# %% [markdown]
# ## 검색버튼으로 검색

# %%
from selenium import webdriver as wb
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup as bs
import time
import pandas as pd
import cx_Oracle
import schedule

# %%
db_data = ['쌀','안심','콩나물','청포묵','미나리','숙주','도라지','고사리','계란','멥쌀','찹쌀','쇠고기','청동호박','흑임자','밀가루','감자','냉면','동치미국물','쇠고기육수','국수','열무','표고버섯','부추','오징어','새우','홍합','김치','만두피','다시마','모시조개','북어','무','미역','다진쇠고기','불린미역','생태','재첩','느타리버섯','양송이버섯','토마토케첩','우엉','잔멸치','갈치','닭','칼국수면','양배추잎','밤','갈비','돼기고기','새우젓','굴','청국장','순두부','동태','가래떡','흰콩','배춧잎','통북어','단무지','해파리','게맛살','멸치젓','풋배추','총각무','꽃게','아구','조기','명란','우거지','팽이버섯','낙지','선지','밥','양','소 잡뼈','사골','도가니','당면','연근','조갯살','냉이','더덕','꽈리고추','마른오징어','돼지갈비','꽁치','통도라지','라면','햄','가는파','굵은파','도토리묵','고등어','가지','마른새우','골뱅이통조림','잣가루','닭고기','유부','목이버섯','양상추','프랑크소시지','곱창','아귀','미더덕','붉은 고추','무순','쑥','솔잎','쇠고기(힘줄없는부위)','토란','찬밥','고구마줄기','쇠고기 육수','통계피','조개살','떡국떡','케일','치커리','청경채','겨자잎','달래','양송이','봄동','옥수수','시금치','말린새우','김치잎','근대잎','불린쌀','게','대하','녹차분말','갑오징어','오곡곡물','코다리','홍차티백','생굴','참치','인절미','고구마','시금치즙','당근즙','고들빼기','두릅','참나물','쭈꾸미','풋마늘','꽁치통조림','채썬쇠고기','김칫잎','순대','열무김치','쌀국수','아욱','떡','새송이버섯','닭봉','오징어채','칼국수','대구','보리','들깻잎','파래','단호박','맛살조개','스위트콘','우묵','골뱅이','생대구','대구살','쌈다시마','무말랭이','육회','얼갈이배추','메주콩','메주','엿기름','건포도','호박씨','근대','순창콩된장','붉은갓','전복','녹차국수','우무','서리태콩','전어','소꼬리','토란탕','멥쌀가루','절임무','참치통조림','돼지고기안심','다진돼지고기','샐러드채소','메기','잉어','물(쇠고기육수)','아기된장소스','쇠고기(안심 또는 등심)','시래기','절인 배추','낙지다리','올리브유','돛나물','노란 파프리카','붉은 파프리카','미니새송이버섯','다진쪽파','고구마잎','호박잎','둥근호박','부침유','어린잎채소','부침가루','당근잎','당근채','배추잎','전분','다짐육','콩비지']

# %%
def lotte():
    dsn=cx_Oracle.makedsn('project-db-stu.ddns.net',1524, 'xe')
    conn=cx_Oracle.connect('cgi_2_0516_1/smhrd1@project-db-stu.ddns.net:1524/xe')
    cur = conn.cursor()

    sql = "delete from mart_price where mart_num = :v1"
    cur.execute(sql,('2'))
    conn.commit()
    conn.close()
    
    name_list = []
    k_name_list = []
    price_list = []
    g_price_list = []
    mart_list = []
    mart_n_list = []

    for j in range(len(db_data)):
        if (db_data[j] == '청동호박'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=호박&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '동치미국물'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=동치미&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '모시조개'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=조개&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '불린미역'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=미역&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] =='생태'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=명태&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '잔멸치'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=멸치&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '양배추잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=양배추&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '배춧잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=배추&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '풋배추'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=배추&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '밥'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=쌀&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '소 잡뼈'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=소뼈&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '조갯살'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=조개&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '가는파'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=파&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '굵은파'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=파&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '잣가루'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=잣&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '붉은 고추'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=고추&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '쇠고기(힘줄없는부위)'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=쇠고기&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '찬밥'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=쌀&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '조개살'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=조개&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '김치잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=김치&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '근대잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=근대&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '불린쌀'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=쌀&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '오곡곡물'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=오곡&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '홍차티백'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=홍차&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '생굴'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=굴&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '시금치즙'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=시금치&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '당근즙'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=당근&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '풋마늘'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=마늘&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '두릅'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=두릅&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '채썬쇠고기'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=소고기&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '김칫잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=김치&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '들깻잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=깻잎&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '맛살조개'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=조개&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '생대구'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=대구&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '대구살'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=대구&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '엿기름'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=기름&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '붉은갓'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=갓김치&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '녹차국수'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=국수&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '토란탕'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=토란&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '멥쌀가루'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=쌀가루&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '절임무'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=무절임&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '메기'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=생선&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '잉어'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=생선&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '물(쇠고기육수)'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=쇠고기육수&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '아기된장소스'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=된장소스&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '낙지다리'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=낙지&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '돛나물'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=나물&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '노란 파프리카'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=파프리카&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '붉은 파프리카'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=파프리카&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '미니새송이버섯'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=새송이버섯&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '다진쪽파'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=쪽파&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '고구마잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=고구마&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '호박잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=호박&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '둥근호박'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=호박&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '부침유'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=식용유&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '어린잎채소'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=잎채소&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '당근잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=당근&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '당근채'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=당근&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        elif (db_data[j] == '배추잎'):
            url = 'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q=배추&mallId=4'
            driver = wb.Chrome()
            driver.get(url)
        else:
            url = f'https://www.lotteon.com/search/search/search.ecn?render=search&platform=pc&q={db_data[j]}&mallId=4'
            driver = wb.Chrome()
            driver.get(url)

        time.sleep(1)

        soup = bs(driver.page_source,'lxml')
        entire = soup.select('div.srchGridProductUnit._dataLayerTarget')

        for i in entire:
            name = i.select('div.srchProductUnitTitle')
            name_list.append(name[len(name)-1].text.strip())

            price = i.select('span.s-product-price__number')
            price_list.append(price[len(price)-1].text)

            mart_list.append('롯데마트')
            mart_n_list.append('2')

            try:
                g_price_list.append(i.select('span.s-product-price__unit')[0].text)
            except:
                g_price_list.append('-')

        for k in range(len(entire)):
            k_name_list.append(db_data[j])

        driver.close()
    for a in range(len(name_list)):
        dsn=cx_Oracle.makedsn('project-db-stu.ddns.net',1524, 'xe')
        conn=cx_Oracle.connect('cgi_2_0516_1/smhrd1@project-db-stu.ddns.net:1524/xe')
        cur = conn.cursor()
        
        sql = "insert into mart_price(mart_num, mart_name, ingr_name, price, price_100, ingr_info_irdnt_sn, ingr_info_irdnt_nm) values(:v1,:v2,:v3,:v4,:v5,:v6,:v7)"
        cur.execute(sql,dict(v1=mart_n_list[a], v2=mart_list[a], v3=name_list[a], v4=price_list[a], v5=g_price_list[a], v6='', v7=k_name_list[a]))
        conn.commit()
    conn.close()

# %%
dic = {'마트번호':mart_n_list,'마트명':mart_list,'카테고리':k_name_list,'상품명':name_list,'가격':price_list,'100g 가격':g_price_list}
df = pd.DataFrame(dic)
df
# df2.to_csv('lotte.csv', index ='false', encoding='ANSI')
# df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4984/3325471177.py in <module>
# ----> 1 dic = {'마트번호':mart_n_list,'마트명':mart_list,'카테고리':k_name_list,'상품명':name_list,'가격':price_list,'100g 가격':g_price_list}
#       2 df = pd.DataFrame(dic)
#       3 df
#       4 # df2.to_csv('lotte.csv', index ='false', encoding='ANSI')
#       5 # df2
#
# NameError: name 'mart_n_list' is not defined

# %%
# 가데이터
dsn=cx_Oracle.makedsn('project-db-stu.ddns.net',1524, 'xe')
conn=cx_Oracle.connect('cgi_2_0516_1/smhrd1@project-db-stu.ddns.net:1524/xe')
cur = conn.cursor()

sql = "insert into mart_price(mart_num, mart_name, ingr_name, price) values(:v1,:v2,:v3,:v4)"
cur.execute(sql,dict(v1='2', v2='롯데마트',v3='1',v4='1'))
conn.commit()
conn.close()

# %%
# delete
dsn=cx_Oracle.makedsn('project-db-stu.ddns.net',1524, 'xe')
conn=cx_Oracle.connect('cgi_2_0516_1/smhrd1@project-db-stu.ddns.net:1524/xe')
cur = conn.cursor()

sql = "delete from mart_price where mart_num = :v1"
cur.execute(sql,('3'))
conn.commit()
conn.close()

# %%
# 스케줄 초기화
schedule.clear()

schedule.every().day.at("07:00").do(lotte)
# Out:
# Every 1 day at 07:00:00 do lotte() (last run: [never], next run: 2022-06-19 07:00:00)

# %%
while True:
    schedule.run_pending()
