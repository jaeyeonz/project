# %%
import requests, xmltodict, json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000226_1/1/1000'
res = requests.get(url)

# %%
dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['Grid_20150827000000000226_1'],ensure_ascii=False)

jsonObj = json.loads(json_string)
df = pd.DataFrame(jsonObj['row'])
df.columns = [
'번호',
'레시피 코드(SEQ_RECIPE)',   
'레시피 이름(한글)',      
'간략(요약) 소개',      
'유형코드',      
'유형분류',      
'음식분류코드',      
'음식분류',      
'조리시간',      
'칼로리',      
'분량',      
'난이도',      
'재료별 분류명',      
'가격별 분류']
df
# Out:
#       번호 레시피 코드(SEQ_RECIPE)  레시피 이름(한글)  \
# 0      1                  1       나물비빔밥
# 1      2                  2         오곡밥
# 2      3                  3         잡채밥
# 3      4                  4        콩나물밥
# 4      5                  5          약식
# ..   ...                ...         ...
# 532  533             180330     식빵고구마파이
# 533  534             180344  카레토마토달걀볶음밥
# 534  535             180363     쪽파 새우강회
# 535  536             195428        누드김밥
# 536  537             195453     콩비지동그랑땡
#
#                                              간략(요약) 소개     유형코드 유형분류   음식분류코드  \
# 0                      육수로 지은 밥에 야채를 듬뿍 넣은 영양만점 나물비빔밥!  3020001   한식  3010001
# 1                       정월대보름에 먹던 오곡밥! 영양을 한그릇에 담았습니다.  3020001   한식  3010001
# 2              잡채밥 한 그릇이면 오늘 저녁 끝! 입 맛 없을 때 먹으면 그만이지요~  3020004   중국  3010001
# 3           다이어트에 으뜸인 콩나물밥. 밥 물 넣을때 평소보다 적게 넣는거 잊지마세요!  3020001   한식  3010001
# 4         집에서도 쉽게 만들어 맛있게 먹을 수 있답니다. 어려워 마시고 만들어 보세요~!  3020001   한식  3010013
# ...

# %%
df.to_csv('food4.csv',encoding='utf-8-sig')

# %%
url = 'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/6001/7000'
res = requests.get(url)
# 재료 정보 1000개단위로 가져오기

# %%
dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['Grid_20150827000000000227_1'],ensure_ascii=False)

jsonObj = json.loads(json_string)
df = pd.DataFrame(jsonObj['row'])
df.columns = [
'번호',
'레시피 코드',   
'재료순번',      
'재료명',      
'재료용량',      
'재료타입 코드',      
'재료타입명'      ]
df
# Out:
#        번호  레시피 코드    재료순번    재료명  재료용량  재료타입 코드 재료타입명
# 0    6001  120401  120406     맛술    2T  3060003    양념
# 1    6002  120401  120405     간장    2T  3060003    양념
# 2    6003  120401  120404    부침유    약간  3060001   주재료
# 3    6004  120401  120403  어린잎채소  100g  3060001   주재료
# 4    6005  120401  120413     통깨    약간  3060003    양념
# ..    ...     ...     ...    ...   ...      ...   ...
# 99   6100  195453  195457     호박  1/2개  3060001   주재료
# 100  6101  195453  195456     대파    1대  3060001   주재료
# 101  6102  195453  195455    다짐육  200g  3060001   주재료
# 102  6103  195453  195454    콩비지  300g  3060001   주재료
# 103  6104  195453  195459   다진마늘    1T  3060001   주재료
#
# [104 rows x 7 columns]

# %%
df.to_csv('recipe4.csv',encoding='utf-8-sig')

# %%
import requests as req
from bs4 import BeautifulSoup as bs
import pandas as pd

# %%
df2 = pd.DataFrame(columns = ['번호',
    '레시피 코드',   
    '재료순번',      
    '재료명',      
    '재료용량',      
    '재료타입 코드',      
    '재료타입명'])

# %%
url1 = 'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/1001/2000'
res = requests.get(url)

# %%
       'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/1001/2000',
       'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/2001/3000',
       'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/3001/4000',
       'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/4001/5000',
       'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/5001/6000',
       'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/6001/7000']

# %%
url1
# Out:
# 'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000227_1/1/1000'

# %%
for i in range(len(url1)):
    url1[i]
    dict_res = xmltodict.parse(res.content)
    json_string = json.dumps(dict_res['Grid_20150827000000000227_1'],ensure_ascii=False)

    jsonObj = json.loads(json_string)
    df = pd.DataFrame(jsonObj['row'])
    df.columns = [
    '번호',
    '레시피 코드',   
    '재료순번',      
    '재료명',      
    '재료용량',      
    '재료타입 코드',      
    '재료타입명']
    df2.append(df)

# %%
df.to_csv('food3.csv',encoding='utf-8-sig')

# %%
df
# Out:
#        번호 레시피 코드  재료순번   재료명   재료용량  재료타입 코드 재료타입명
# 0    1001     86  1001  다진마늘    3큰술  3060003    양념
# 1    1002     86  1002    생강   1/2쪽  3060003    양념
# 2    1003     86  1003   홍고추     3개  3060002   부재료
# 3    1004     86  1004   멸치젓   1/2컵  3060003    양념
# 4    1005     86  1005  고춧가루   1/2컵  3060003    양념
# ..    ...    ...   ...   ...    ...      ...   ...
# 995  1996    177  1996  다진마늘     약간  3060002   부재료
# 996  1997    177  1997     물     7컵  3060002   부재료
# 997  1998    177  1998    간장     약간  3060003    양념
# 998  1999    177  1999    소금     약간  3060003    양념
# 999  2000    177  2000    대파  1/4뿌리  3060002   부재료
#
# [1000 rows x 7 columns]

# %%
df2=0

# %%
url = 'http://211.237.50.150:7080/openapi/7c88a2213bf000b6cde0353a1889ca8cd1d5aaaca32feb487e433a25f4d0e24b/xml/Grid_20150827000000000228_1/3001/4000'
res = requests.get(url)
# 과정정보 1000개단위

# %%
df.to_csv('process4.csv',encoding='utf-8-sig')

# %%
dict_res = xmltodict.parse(res.content)
json_string = json.dumps(dict_res['Grid_20150827000000000228_1'],ensure_ascii=False)

jsonObj = json.loads(json_string)
df = pd.DataFrame(jsonObj['row'])
df.columns = [
'번호',
'레시피 코드',      
'요리설명순서',      
'요리설명',      
'과정 이미지 URL',      
'과정팁'          ]
df
# Out:
#       번호  레시피 코드 요리설명순서                                             요리설명  \
# 0   3001  180344      9                           그릇에 볶음밥과 카레소스를 함께 담는다.
# 1   3002  180363      1                        새우와 쪽파는 데치기 전에 깨끗하게 손질한다.
# 2   3003  180363      2        쪽파는 끓는 물에 소금을 넣고 살짝 데친 후 찬물에 담갔다 물기를 빼준다.
# 3   3004  180363      3                         새우는 끓는 물에 소금을 약간 넣고 데친다.
# 4   3005  180363      4          그릇에 고추장, 식초, 설탕, 깨를 넣고 잘 섞어 초장을 만들어 준다.
# 5   3006  180363      5                            새우에 쪽파를 감아 접시에 담아 준다.
# 6   3007  195428      1               당근과 오이는 얇게 슬라이스 해준다.\n가지는 길게 잘라준다.
# 7   3008  195428      2                   오이를 제외한 당근과 가지를 기름 두른 팬에 볶아준다.
# 8   3009  195428      3                 밥에 통깨와 참기름  맛소금을 넣고 주걱을 세워 섞어준다.
# 9   3010  195428      4       김말이 위에 랩을 깔아주고 김을 올려놓고 밥을 김 위에 잘 펴 뒤집어 준다.
# 10  3011  195428      5                뒤집은 김위에 김밥속 재료인 당근, 가지, 오이를 올려준다.
# 11  3012  195428      6                           김발과 랩을 빼 주며 김밥을 말아 준다.
# ...
